# %% [markdown]
# <a href="https://colab.research.google.com/github/skshrivastava007/desktop-tutorial/blob/main/google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Documentation for the `google.colab` Python package.

# %% [markdown]
# # google.colab.data_table
#
# See https://colab.research.google.com/notebooks/data_table.ipynb

# %% [markdown]
# # google.colab.drive
#
# Mount your Google Drive on your runtime using an authorization code to enable reading and writing files there.

# %%
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# # google.colab.files

# %% [markdown]
# ### files.download()
# `files.download()` downloads a file from the runtime to the user's local computer.

# %%
from google.colab import files
files.download('/content/sample_data/README.md')

# %% [markdown]
# ### files.upload()
#
# `files.upload()` prompts users to upload files from their local machine to the rutnime. It returns a dictionary of the files which were uploaded. The dictionary is keyed by the file name and values are the data which were uploaded.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %% [markdown]
# ### files.view()
# `files.view()` allows opening files and directories in the UI.

# %%
from google.colab import files

files.view('sample_data/README.md')

# %% [markdown]
# Use it to easily open source files.

# %%
from google.colab import files

files.view(files.__file__)

# %% [markdown]
# Directories will be opened in the file browser.

# %%
from google.colab import files

files.view('/var/log')

# %% [markdown]
# # google.colab.output
#
# See https://colab.research.google.com/notebooks/snippets/advanced_outputs.ipynb

# %% [markdown]
# # google.colab.syntax
#
# `syntax` is a helper which returns the string passed into it but allows the editor to add language-specific syntax highlighting and completions.

# %%
from google.colab import syntax

query = syntax.sql('''
  SELECT * FROM my_table WHERE STRPOS(Request, '/data') > 0
''')
print(query)

html = syntax.html('''
  <marquee id="element">Some text</marquee>
''')
print(html)

# %%
# Ideal gas equation: PV = nRT
# R = 0.0821 atm L /mole K
# Inputs:
P = 10 # atm
n = 2 # mole
T = 300 # K
# Calculate volume
V = n * 0.0821 * T / P
print(f'gas volume: {V:.2f} L')
# Out:
# gas volume: 4.93 L
